# %% [markdown]
# # BL40A2010 Introduction to IoT-Based Systems
#
# ## Assignment 5, DD.MM.YYYY
#
# ### Author:

# %% [markdown]
# **(1) Create two arrays with 10000 samples generated as [Binomial](https://en.wikipedia.org/wiki/Binomial_distribution) random variables via [Numpy](https://docs.scipy.org/doc/numpy/reference/generated/numpy.random.binomial.html) similar to what we have done with Poisson random variables in the tutorial considering the following paramenters of the Binomial function:**
#
# **(a) $n=100$ and $p=0.3$;**
#
# **(b) $n=10000$, and $p=0.6$**
#
#
# **Make the histogram (empirical) plots related to each vector and compare them with the analytical results with the probability distribution funtion given by:**
#
# **$$\mathrm{Prob}\left[X = k \right] = \binom{n}{k}p^k(1-p)^{n-k},$$ where $k$ is the number of *successes* in $n$ trials.**
#
# **Remember to use this [scipy.stats.binom](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.binom.html) in a similar way we did in the tutorial with Poisson.**

# %%
pip install --upgrade networkx
# Out:
# Requirement already up-to-date: networkx in /srv/conda/envs/notebook/lib/python3.7/site-packages (2.5)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from networkx) (4.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in /srv/conda/envs/notebook/lib/python3.7/site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.14.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from scipy) (1.18.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib import style
from scipy.stats import binom
style.use('bmh')
import warnings
warnings.filterwarnings('ignore')

# %%
x = np.random.binomial(n=100, p=0.3, size = 1000)
y = np.arange(binom.ppf(0.01, 100, p), 
              binom.ppf(0.99, 100, p))
avg = np.max(x)-np.min(x)

plt.figure(figsize=(14,5))
plt.hist(x, avg,density=True)
#plt.step(y, binom.pmf(y, n, p), where='post')
plt.xlabel('$n$')
plt.ylabel('Frequency of $N = n$')
plt.title('Binom distribution')
plt.show()

print(binom.pmf(y, n, p))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-130-3d49e6da0886> in <module>
#      12 plt.show()
#      13
# ---> 14 print(binom.pmf(y, n, p))
#      15
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py in pmf(self, k, *args, **kwds)
#    3023         k = asarray((k-loc))
#    3024         cond0 = self._argcheck(*args)
# -> 3025         cond1 = (k >= _a) & (k <= _b) & self._nonzero(k, *args)
#    3026         cond = cond0 & cond1
#    3027         output = zeros(shape(cond), 'd')
#
# ValueError: operands could not be broadcast together with shapes (21,) (75,)

# %%
samples = 10000
p = 0.6
n = np.arange(9*p)
distribution = np.random.binomial(samples, p, 10000)
avg = np.max(distribution) - np.min(distribution)

plt.figure(figsize=(14,5))
plt.hist(distribution, avg, density=True)
#plt.step(n, poisson.pmf(n, p), where='post')
plt.xlabel('$n$')
plt.ylabel('Frequency of $N = n$')
plt.title('Poisson distribution')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-31851de20bcb> in <module>
#       1 n = 10000
#       2 p = 0.6
# ----> 3 distribution = np.random.poisson(mean, samples)
#       4 avg = np.max(distribution) - np.min(distribution)
#       5 plt.figure(figsize=(14,5))
#
# NameError: name 'mean' is not defined

# %% [markdown]
# **(2) Read Section 2.3 and Chapter 3 from [Network Science](http://networksciencebook.com/) and generate three different kinds of Erdos-Renyi graphs with $N=15$ (fifteen nodes) using [NetworkX](https://networkx.github.io/documentation/stable/reference/generated/networkx.generators.random_graphs.erdos_renyi_graph.html?highlight=erdos#networkx.generators.random_graphs.erdos_renyi_graph).
# The networks shall be (a)  with probability $p=0.2$, (b) with probability $p=0.5$ and (c) with probability $p=0.8$. Discuss about the differences you see if these graphs represent communication networks.**
